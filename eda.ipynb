# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('adult 3.csv')
df.columns = df.columns.str.strip()
print("Column names saaf ho gaye hain. Ab koi extra space nahi hai.")
# Out:
# Column names saaf ho gaye hain. Ab koi extra space nahi hai.

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.tail(7)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 48835  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 48836       Never-married    Protective-serv  Not-in-family  White    Male
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.age.value_counts()
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df.gender.value_counts()
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
df['native-country']=df['native-country'].replace({'?':'Other'})

# %%
df['workclass']=df['workclass'].replace({'?':'Not Listed'})

# %%
df['occupation']=df['occupation'].replace({'?':'Others'} )

# %%
print(df.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# Not Listed           2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#Dimensionality Reduction

# %%
df=df[df['workclass']!='Without-pay']

# %%
df=df[df['workclass']!='Never-worked']

# %%
df=df[df['native-country']!='Holand-Netherlands']

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33905
# Self-emp-not-inc     3862
# Local-gov            3136
# Not Listed           2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
#Redundancy
df.drop(columns=['education'],inplace=True)

# %%
df
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18    Not Listed  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %%
df.shape
# Out:
# (48810, 14)

# %%
#outlier
import matplotlib.pyplot as plt

plt.boxplot(df['age'])
plt.show()

# %%
df=df[(df['age']<=75)&(df['age']>=17)]

# %%
plt.boxplot(df['age'])
plt.show()

# %%
plt.boxplot(df['educational-num'])
plt.show()

# %%
df=df[df['educational-num']>=5]

# %%
plt.boxplot(df['educational-num'])
plt.show()

# %%
df['hours-per-week'].value_counts()
# Out:
# hours-per-week
# 40    21798
# 50     4151
# 45     2646
# 60     2134
# 35     1836
#       ...
# 94        1
# 82        1
# 87        1
# 69        1
# 79        1
# Name: count, Length: 96, dtype: int64

# %%
plt.boxplot(df['hours-per-week'])
plt.show()

# %%
df=df[(df['hours-per-week']<=50)&(df['hours-per-week']>=37)]

# %%
#df['hours-per-week'].value_counts()

# %%
plt.boxplot(df['hours-per-week'])
plt.show()

# %%
df.head()
# Out:
#    age   workclass  fnlwgt  educational-num      marital-status  \
# 0   25     Private  226802                7       Never-married
# 1   38     Private   89814                9  Married-civ-spouse
# 2   28   Local-gov  336951               12  Married-civ-spouse
# 3   44     Private  160323               10  Married-civ-spouse
# 6   29  Not Listed  227026                9       Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
# 2    Protective-serv      Husband  White   Male             0             0
# 3  Machine-op-inspct      Husband  Black   Male          7688             0
# 6             Others    Unmarried  Black   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['workclass'] = encoder.fit_transform(df['workclass'])
df['marital-status'] = encoder.fit_transform(df['marital-status'])
df['occupation'] = encoder.fit_transform(df['occupation'])
df['relationship'] = encoder.fit_transform(df['relationship'])
df['race'] = encoder.fit_transform(df['race'])
df['gender'] = encoder.fit_transform(df['gender'])
df['native-country'] = encoder.fit_transform(df['native-country'])
df
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 6       29          2  227026                9               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48836   22          3  310152               10               4          11
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48841   52          4  287927                9               2           3
#
# ...

# %%
# Setting Features and Targets
# Yahaan hum target ('income') aur leaking feature ('relationship') dono ko hata rahe hain.
x = df.drop(['income', 'relationship'], axis=1)
y = df['income']

print("Features for the model are now correctly defined.")
# Out:
# Features for the model are now correctly defined.

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 6       29          2  227026                9               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48836   22          3  310152               10               4          11
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48841   52          4  287927                9               2           3
#
#        race  gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 6        <=50K
#          ...
# 48836    <=50K
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48841     >50K
# Name: income, Length: 31482, dtype: object

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='income', data=df, palette='Set2')
plt.title('Income Distribution', fontsize=14)
plt.xlabel('Income Category', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# /var/folders/fw/7gp_wk4n0mj_vqrj_25cfh6h0000gn/T/ipykernel_73550/3209905252.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='income', data=df, palette='Set2')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', hue='income', data=df, palette='Set1')
plt.title('Gender-wise Income Distribution', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Income')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.xticks([0, 1], ['Male', 'Female'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='educational-num', hue='income', data=df,
              order=df['educational-num'].value_counts().index,
              palette=['black' , 'crimson' ])
plt.title('Income by Education Level', fontsize=14)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Education Level', fontsize=12)
plt.legend(title='Income')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(x='income', y='hours-per-week', data=df, palette='Pastel1')
plt.title('Working Hours by Income Category', fontsize=14)
plt.xlabel('Income Category', fontsize=12)
plt.ylabel('Hours per Week', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.4)
plt.show()
# Out:
# /var/folders/fw/7gp_wk4n0mj_vqrj_25cfh6h0000gn/T/ipykernel_73550/1127516753.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='income', y='hours-per-week', data=df, palette='Pastel1')

# %%
from sklearn.preprocessing import LabelEncoder

# Apply Label Encoding to the 'income' column
encoder = LabelEncoder()
df['income_encoded'] = encoder.fit_transform(df['income'])

plt.figure(figsize=(12, 10))
# Calculate correlation matrix excluding the original 'income' column but including the encoded one
corr_matrix = df.drop('income', axis=1).corr()
sns.heatmap(corr_matrix, annot=True, fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Features (with encoded income)', fontsize=16)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Lasso, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import Binarizer,StandardScaler,OneHotEncoder

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42,stratify=y)

# %%
print(df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income',
#        'income_encoded'],
#       dtype='object')

# %%
#Setting Features and Targets
df.dropna(inplace=True)
# Ensure this is the code in your notebook
x = df.drop(['income', 'income_encoded', 'relationship'], axis=1)
y = df['income']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
print("Type after split:", type(x_train)) # This should print <class 'pandas.core.frame.DataFrame'>
# Out:
# Type after split: <class 'pandas.core.frame.DataFrame'>

# %%
# Make sure no code between the split and here converts the type to a numpy array.

numerical_cols = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
scaler = StandardScaler()

x_train[numerical_cols] = scaler.fit_transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])

print("\n✅ Numerical features scaled successfully.")
# Out:
# ✅ Numerical features scaled successfully.

# %%
# from sklearn.preprocessing import StandardScaler
# st_x= StandardScaler()
# x_train= st_x.fit_transform(x_train)
# x_test= st_x.transform(x_test)

# %%
from imblearn.over_sampling import SMOTE

# See the class distribution before balancing
print("Class distribution before SMOTE:")
print(y_train.value_counts())

smote = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train)

# See the class distribution after balancing
print("\nClass distribution after SMOTE:")
print(y_train_resampled.value_counts())
# Out:
# Class distribution before SMOTE:
# income
# <=50K    18427
# >50K      6758
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# income
# <=50K    18427
# >50K     18427
# Name: count, dtype: int64
# /Users/manvidhamija/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
# 1. Categorical features ko Label Encode karein (jaisa aapne kiya hai)
# ... aapka label encoding ka code yahaan aayega ...
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# 2. **CRITICAL STEP**: Numerical features ko ab SCALE karein
numerical_cols = x_train.select_dtypes(include=np.number).columns
scaler = StandardScaler()
x_train[numerical_cols] = scaler.fit_transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])
print("Data sahi samay par scale ho gaya hai.")

# 3. Ab scaled training data par SMOTE apply karein
smote = SMOTE(random_state=42)
x_train_res, y_train_res = smote.fit_resample(x_train, y_train)
print("SMOTE aapply ho gaya hai.")

# 4. Ab AAKHIR mein, model ko is naye, saaf data par TRAIN karein
gbc = GradientBoostingClassifier(random_state=42)
gbc.fit(x_train_res, y_train_res)
print("Model ab sahi data par train ho gaya hai.")
# Out:
# Data sahi samay par scale ho gaya hai.
# /Users/manvidhamija/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# SMOTE aapply ho gaya hai.
# Model ab sahi data par train ho gaya hai.

# %%
#Classification models
# Model 1: Decision Tree
#Fitting Decision Tree classifier to the training set
from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(criterion='entropy', random_state=0)
classifier.fit(x_train, y_train)

#Predicting the test set result
y_pred= classifier.predict(x_test)

# %%
#Creating the Confusion matrix
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[3938,  669],
#        [ 655, 1035]])

# %%
from sklearn import tree
tree.plot_tree(classifier)
# Out:
# [Text(0.6536163581976457, 0.9918032786885246, 'x[4] <= 0.006\nentropy = 0.839\nsamples = 25185\nvalue = [18427, 6758]'),
#  Text(0.360868984580011, 0.9754098360655737, 'x[4] <= -1.346\nentropy = 0.963\nsamples = 16012\nvalue = [9818, 6194]'),
#  Text(0.5072426713888284, 0.9836065573770492, 'True  '),
#  Text(0.08611426953408446, 0.9590163934426229, 'x[8] <= 0.873\nentropy = 0.469\nsamples = 3757\nvalue = [3381, 376]'),
#  Text(0.07077958311069159, 0.9426229508196722, 'x[3] <= 0.967\nentropy = 0.392\nsamples = 3659\nvalue = [3377, 282]'),
#  Text(0.04943808514929299, 0.9262295081967213, 'x[10] <= 0.954\nentropy = 0.256\nsamples = 2972\nvalue = [2844, 128]'),
#  Text(0.03865083259350434, 0.9098360655737705, 'x[9] <= 5.173\nentropy = 0.208\nsamples = 2624\nvalue = [2538, 86]'),
#  Text(0.02974414045038433, 0.8934426229508197, 'x[5] <= 0.303\nentropy = 0.196\nsamples = 2610\nvalue = [2531, 79]'),
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score (y_test,y_pred)
# Out:
# 0.7897411465777354

# %%
# Model 2 : Random Forest
#Fitting Decision Tree classifier to the training set
from sklearn.ensemble import RandomForestClassifier
classifier1= RandomForestClassifier(n_estimators= 3, criterion="entropy")
classifier1.fit(x_train, y_train)
y_pred1= classifier1.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred1)
cm
# Out:
# array([[4023,  584],
#        [ 637, 1053]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score (y_test,y_pred1)
# Out:
# 0.8060981419723678

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
# Naive Bayes
results={}
gnb = GaussianNB()
gnb.fit(x_train, y_train)
results['Gaussian NB'] = accuracy_score(y_test, gnb.predict(x_test))

bnb = BernoulliNB()
bnb.fit(x_train, y_train)
results['Bernoulli NB'] = accuracy_score(y_test, bnb.predict(x_test))

from sklearn.preprocessing import MinMaxScaler

# Prepare unscaled version just for MultinomialNB
X_unscaled = df.drop(['income', 'income_encoded'], axis=1) # Drop both original and encoded income
y = df['income']
X_train_unscaled, X_test_unscaled, y_train_unscaled, y_test_unscaled = train_test_split(
    X_unscaled, y, test_size=0.2, random_state=42)

# Apply MinMaxScaler to ensure all features are non-negative
minmax = MinMaxScaler()
X_train_mnb = minmax.fit_transform(X_train_unscaled)
X_test_mnb = minmax.transform(X_test_unscaled)

# Fit MultinomialNB
mnb = MultinomialNB()
mnb.fit(X_train_mnb, y_train_unscaled)
results['Multinomial NB'] = accuracy_score(y_test_unscaled, mnb.predict(X_test_mnb))

# %%
print(" Naive Bayes Model Accuracy Comparison:")
for model, acc in results.items():
    print(f"{model}: {acc:.4f}")
# Out:
#  Naive Bayes Model Accuracy Comparison:
# Gaussian NB: 0.7739
# Bernoulli NB: 0.7975
# Multinomial NB: 0.7451

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=10000)
logreg.fit(x_train, y_train)
accuracy_score(y_test, logreg.predict(x_test))
# Out:
# 0.8024456090201684

# %%
#Date-10 July 2025(Thursday)
#Svm and k-means clustering

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='rbf', probability=True, random_state=0)
model.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True, random_state=0)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, mean_absolute_error, mean_squared_error

# Predicted labels
y_pred_svm = model.predict(X_test_scaled)

# Accuracy
accuracy = accuracy_score(y_test, y_pred_svm)
print('Accuracy: ', accuracy)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# F1 Score
# Sahi code, jismein hum positive class ka numerical label (1) istemal kar rahe hain
f1 = f1_score(y_test, y_pred, pos_label=1)
print('F1 Score: ', f1)
# Out:
# Accuracy:  0.8261076703191996
# Confusion Matrix:
# [[3938  669]
#  [ 655 1035]]
# F1 Score:  0.6098998232174425

# %%
from sklearn.metrics import log_loss, roc_auc_score
y_prob = model.predict_proba(X_test_scaled)[:, 1]
# Logarithmic Loss
log_loss_value = log_loss(y_test, y_prob)
print('Logarithmic Loss: ', log_loss_value)

# Area Under Curve (AUC)
auc = roc_auc_score(y_test, y_prob)
print('Area Under Curve (AUC): ', auc)
# Out:
# Logarithmic Loss:  0.3995824834505968
# Area Under Curve (AUC):  0.8692992911481499

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predict_knn=knn.predict(x_test)
accuracy_score(y_test,predict_knn)
# Out:
# 0.8024456090201684

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier()
mlp.fit(x_train,y_train)
predict_mlp=mlp.predict(x_test)
accuracy_score(y_test,predict_mlp)
# Out:
# /Users/manvidhamija/Library/Python/3.9/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.8284897570271558

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predict_gbc=gbc.predict(x_test)
accuracy_score(y_test,predict_gbc)
# Out:
# 0.8486580911545181

# %%
#Hyper Parameter Tuning
from sklearn.model_selection import GridSearchCV

params = {'n_estimators': [100, 200],
          'max_depth': [4, 6, 8]}

grid = GridSearchCV(RandomForestClassifier(), params, cv=5)
grid.fit(x_train, y_train)
print(grid.best_params_)
predict_grid = grid.predict(x_test)
accuracy_score(y_test, predict_grid)
# Out:
# {'max_depth': 8, 'n_estimators': 200}
# 0.8356360171510243

# %%
#Ensemble Techniques:
import xgboost 
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
voting = VotingClassifier(estimators=[
    ('lr', LogisticRegression()),
    ('rf', RandomForestClassifier()),
    ('xgb', XGBClassifier())], voting='soft')
voting.fit(x_train, y_train)
predict_voting = voting.predict(x_test)
accuracy_score(y_test, predict_voting)
# Out:
# 0.8453231697633794

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

# Dictionary to hold all models and their predictions
models = {
    "Decision Tree": classifier.predict(x_test),
    "Random Forest": classifier1.predict(x_test),
    "Logistic Regression": logreg.predict(x_test),
    "Gaussian NB": gnb.predict(x_test),
    "Bernoulli NB": bnb.predict(x_test),
    "Multinomial NB": mnb.predict(X_test_mnb) ,
    "Support Vector Machine(SVM)" :model.predict(X_test_scaled) ,
    "KNeighbors Classifier":knn.predict(x_test),
    "MLP Classifier":mlp.predict(x_test),
    "Gradient Boosting Classifier":gbc.predict(x_test),
    "Ensemble-Voting Classifier":voting.predict(x_test),
    "Grid Search CV":grid.predict(x_test)
}

# Create a comparison DataFrame
comparison = []

for model_name, predictions in models.items():
    # For Multinomial NB, predictions are already in string format and based on X_test_mnb
    if model_name == "Multinomial NB":
        current_y_test = y_test_unscaled # Use the unscaled y_test for Multinomial NB
        current_predictions = predictions
    else:
        # Use the original y_test and predictions for other models
        current_y_test = y_test
        current_predictions = predictions


    acc = accuracy_score(current_y_test, current_predictions)
    # Use the original string labels for metric calculations
    # Specify positive label for binary classification
    # Sahi code, jismein hum positive class ka numerical label (1) istemal kar rahe hain
    # Sahi code, jismein hum positive class ka text label ('>50K') istemal kar rahe hain
    # Sahi code, jismein hum positive class ka numerical label (1) istemal kar rahe hain
# Kyunki current_y_test ab [0, 1] format mein hai
    # prec = precision_score(current_y_test, current_predictions, pos_label=1)
    # rec = recall_score(current_y_test, current_predictions, pos_label=1)
    # f1 = f1_score(current_y_test, current_predictions, pos_label=1)

  

    comparison.append({
        "Model": model_name,
        "Accuracy": round(acc, 4),
        "Precision": round(prec, 4),
        "Recall": round(rec, 4),
        "F1 Score": round(f1, 4)
    })

comparison_df = pd.DataFrame(comparison).sort_values(by="F1 Score", ascending=False)
print(comparison_df)
print("\nBest Classification Model:", comparison_df.iloc[0]["Model"])
# Out:
#                            Model  Accuracy  Precision  Recall  F1 Score
# 0                  Decision Tree    0.7897     0.6347  0.5787    0.6099
# 1                  Random Forest    0.8061     0.6347  0.5787    0.6099
# 2            Logistic Regression    0.8024     0.6347  0.5787    0.6099
# 3                    Gaussian NB    0.7739     0.6347  0.5787    0.6099
# 4                   Bernoulli NB    0.7975     0.6347  0.5787    0.6099
# 5                 Multinomial NB    0.7451     0.6347  0.5787    0.6099
# 6    Support Vector Machine(SVM)    0.8261     0.6347  0.5787    0.6099
# 7          KNeighbors Classifier    0.8024     0.6347  0.5787    0.6099
# 8                 MLP Classifier    0.8285     0.6347  0.5787    0.6099
# 9   Gradient Boosting Classifier    0.8487     0.6347  0.5787    0.6099
# 10    Ensemble-Voting Classifier    0.8453     0.6347  0.5787    0.6099
# 11                Grid Search CV    0.8356     0.6347  0.5787    0.6099
#
# ...

# %%
#Make Chart for all models
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(comparison_df["Model"], comparison_df["Accuracy"], color='crimson')
plt.ylabel('Accuracy Score')
plt.title('Model Comparison')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import joblib

# Save Gradient Boosting Classifier
joblib.dump(gbc, "gradient_boosting_model.pkl")
print("✅ Gradient Boosting model saved successfully.")
# Out:
# ✅ Gradient Boosting model saved successfully.

# %%
# This assumes you already have the ensemble model object created, for example:
# from sklearn.ensemble import VotingClassifier
# ensemble = VotingClassifier(estimators=[('rf', rf), ('svc', svc_model)], voting='hard')
# ensemble.fit(X_train, y_train)

# Now save the second-best model (Ensemble-Voting Classifier)
# import joblib

# second_best_model_object = voting  # replace 'ensemble' with your actual ensemble model variable
# joblib.dump(second_best_model_object, "best_model.pkl")
# print("✅ 2nd best model (Ensemble-Voting Classifier) saved as best_model.pkl")

# %%
import joblib

# In your notebook, you defined the Gradient Boosting Classifier model
# and assigned it to the variable 'gbc'.
# We will now save that specific model object.

# The variable 'gbc' holds your trained Gradient Boosting Classifier
joblib.dump(gbc, "best_model.pkl")

print("✅ Gradient Boosting Classifier model (from variable 'gbc') saved as 'best_model.pkl' successfully!")
# Out:
# ✅ Gradient Boosting Classifier model (from variable 'gbc') saved as 'best_model.pkl' successfully!

# %%
# In your Jupyter Notebook

from sklearn.preprocessing import StandardScaler
import joblib

# Define the numerical columns
numerical_cols = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# Create the scaler object
scaler = StandardScaler()

# --- THIS IS THE CRITICAL FIX ---
# Fit the scaler ONLY on the numerical columns of the training data.
scaler.fit(x_train[numerical_cols])
# ------------------------------

# Now, transform the numerical columns of both the training and test sets
x_train[numerical_cols] = scaler.transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])

print("✅ Scaler has been correctly fitted on numerical columns only.")

# --- Save the CORRECTLY trained scaler ---
joblib.dump(scaler, "scaler.pkl")
print("✅ Correctly trained scaler has been saved to 'scaler.pkl'.")
# Out:
# ✅ Scaler has been correctly fitted on numerical columns only.
# ✅ Correctly trained scaler has been saved to 'scaler.pkl'.

# %%
# import joblib

# # Ensure your features X were defined correctly before this point:
# # X = df.drop(['income', 'income_encoded', 'relationship'], axis=1)
# # And that your model ('gbc') and scaler ('scaler') were trained on that data.

# # Save the final, correctly trained Gradient Boosting model
# joblib.dump(gbc, "best_model.pkl")
# print("✅ Final, correct model saved as 'best_model.pkl'.")

# # Save the final, correctly trained scaler
# joblib.dump(scaler, "scaler.pkl")
# print("✅ Final, correct scaler saved as 'scaler.pkl'.")

# %%
# second_model_name = comparison_df.iloc[1]["Model"]
# second_model_accuracy = comparison_df.iloc[1]["Accuracy"]
# print(f"✅ Second best model: {second_model_name} with accuracy {second_model_accuracy:.4f}")

# # Assuming you have your models dict defined:
# models = {
#     "Logistic Regression": log_reg,
#     "Decision Tree": dt,
#     "Random Forest": rf,
#     "SVM": svm_model,
#     "KNN": knn,
#     "Multinomial NB": mnb,
#     # add other models here
# }

# # Retrieve the 2nd best model
# second_best_model_object = models.get(second_model_name, None)

# if second_best_model_object is not None:
#     joblib.dump(second_best_model_object, "best_model.pkl")
#     print("✅ Second best model saved as best_model.pkl")
# else:
#     print(f"❌ Could not find model object for '{second_model_name}' in models dictionary.")

# %%
import joblib

# This saves the model that was trained WITHOUT 'relationship'
joblib.dump(gbc, "best_model_1.pkl")

# Define the numerical columns
numerical_cols = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# Create the scaler object
scaler = StandardScaler()

# --- THIS IS THE CRITICAL FIX ---
# Fit the scaler ONLY on the numerical columns of the training data.
scaler.fit(x_train[numerical_cols])
# ------------------------------

# Now, transform the numerical columns of both the training and test sets
x_train[numerical_cols] = scaler.transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])


# This saves the scaler that was trained correctly
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
import pickle
from sklearn.preprocessing import LabelEncoder

# --- YEH ZAROORI STEP HAI ---
# Istemal karne se theek pehle, 'categorical_cols' ko dobara define karein.
# Yeh 'X' DataFrame se saari text wali (object) columns ki list nikalega.
# 'X' woh DataFrame hai jismein aapke saare features hain (bina encoding ke).
categorical_cols = X.select_dtypes(include=['object']).columns
# -----------------------------

le_dict = {}
for col in categorical_cols:
    le = LabelEncoder()
    # Har encoder ko uski original text column par fit karein
    le.fit(X[col])
    le_dict[col] = le

# Ab saare fitted encoders ko ek file mein save karein
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(le_dict, f)

print("✅ Saare Label Encoders 'label_encoders.pkl' naam se save ho gaye hain.")
# Out:
# ✅ Saare Label Encoders 'label_encoders.pkl' naam se save ho gaye hain.
